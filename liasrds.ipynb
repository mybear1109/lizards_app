# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import joblib

# %%
df = pd.read_csv('model/thebreeder.csv')

# %%
df.head()
# Out:
#                                         path  \
# 0  /content/drive/MyDrive/thebreeders/image/
# 1  /content/drive/MyDrive/thebreeders/image/
# 2  /content/drive/MyDrive/thebreeders/image/
# 3  /content/drive/MyDrive/thebreeders/image/
# 4  /content/drive/MyDrive/thebreeders/image/
#
#                                image_id  \
# 0  e09c44ef94f27743c60a9e7aaab46e60.jpg
# 1  ae4369471d5ecdc865bf1e7eee012cff.jpg
# 2  e6b0a9a3a56d071444312b11c49881d1.jpg
# 3  cb1a39623e2751e70943a39681d2fe78.jpg
# 4  ece3344eff3edeac0de436c7d3ccb314.jpg
#
#                                                image  \
# 0  /content/drive/MyDrive/thebreeders/image/e09c4...
# 1  /content/drive/MyDrive/thebreeders/image/ae436...
# 2  /content/drive/MyDrive/thebreeders/image/e6b0a...
# 3  /content/drive/MyDrive/thebreeders/image/cb1a3...
# 4  /content/drive/MyDrive/thebreeders/image/ece33...
#
#                           trans        type       size      morph    price  \
# ...

# %%
df.isna().sum()
# Out:
# path              0
# image_id          0
# image             0
# trans             0
# type              0
# size              0
# morph             0
# price             0
# text              0
# date              0
# Unnamed: 10    1232
# Unnamed: 11    1232
# Unnamed: 12    1231
# dtype: int64

# %%
df.drop(columns=['path', 'image','Unnamed: 10','Unnamed: 11','Unnamed: 12'], inplace=True)

# %%
df.head()
# Out:
#                                image_id                         trans  \
# 0  e09c44ef94f27743c60a9e7aaab46e60.jpg              white tree frock
# 1  ae4369471d5ecdc865bf1e7eee012cff.jpg       Albino Spanish Lip Newt
# 2  e6b0a9a3a56d071444312b11c49881d1.jpg                  green pacman
# 3  cb1a39623e2751e70943a39681d2fe78.jpg  Bard Tiger Salamander Female
# 4  ece3344eff3edeac0de436c7d3ccb314.jpg       female tiger salamander
#
#          type       size      morph    price             text    date
# 0        frog  undefined      white   30,000          화이트트리프록  202404
# 1        newt  undefined     albino   40,000     알비노 스패니쉬립 뉴트  202405
# 2      pacman  undefined      green   30,000            그린 팩맨  202210
# 3  Salamander      adult  undefined   75,000  바드 타이거 살라멘더 암성체  202409
# 4  Salamander      adult  undefined  160,000     타이거 살라멘더 암성체  202409

# %%
df.to_csv('Lizards.csv', index=False, encoding='utf-8')
